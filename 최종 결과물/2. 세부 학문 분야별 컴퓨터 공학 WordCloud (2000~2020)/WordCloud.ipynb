# %%
from google.colab import drive 
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from collections import Counter
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# %%
cate = pd.read_csv('/content/drive/MyDrive/pp/Web, Mobile and Multimedia Technologies_pre.csv', encoding='utf-8')
cate.head()
# Out:
#    Unnamed: 0  ...    year
# 0           0  ...  2000.0
# 1           1  ...  2000.0
# 2           2  ...  2000.0
# 3           3  ...  2000.0
# 4           4  ...  2000.0
#
# [5 rows x 11 columns]

# %%
from ast import literal_eval
cate['keyword'] = cate.keyword.apply(lambda x: literal_eval(str(x)))

# %%
cate['keyword'].iloc[0]
# Out:
# ['lurking',
#  'groups',
#  'group',
#  'dls',
#  'fewer',
#  'reports',
#  'reported',
#  'levels',
#  'level']

# %%
keyword2000 = cate[cate.year == 2000].keyword 
keyword2000 = [word for words in keyword2000 for word in words]

keyword2001 = cate[cate.year == 2001].keyword 
keyword2001 = [word for words in keyword2001 for word in words]

keyword2002 = cate[cate.year == 2002].keyword 
keyword2002 = [word for words in keyword2002 for word in words]

keyword2003 = cate[cate.year == 2003].keyword 
keyword2003 = [word for words in keyword2003 for word in words]

keyword2004 = cate[cate.year == 2004].keyword 
keyword2004 = [word for words in keyword2004 for word in words]

keyword2005 = cate[cate.year == 2005].keyword 
keyword2005 = [word for words in keyword2005 for word in words]

keyword2006 = cate[cate.year == 2006].keyword 
keyword2006 = [word for words in keyword2006 for word in words]

keyword2007 = cate[cate.year == 2007].keyword 
keyword2007 = [word for words in keyword2007 for word in words]

keyword2008 = cate[cate.year == 2008].keyword 
keyword2008 = [word for words in keyword2008 for word in words]

keyword2009 = cate[cate.year == 2009].keyword 
keyword2009 = [word for words in keyword2009 for word in words]

keyword2010 = cate[cate.year == 2010].keyword 
keyword2010 = [word for words in keyword2010 for word in words]

keyword2011 = cate[cate.year == 2011].keyword 
keyword2011 = [word for words in keyword2011 for word in words]


keyword2012 = cate[cate.year == 2012].keyword 
keyword2012 = [word for words in keyword2012 for word in words]

keyword2013 = cate[cate.year == 2013].keyword 
keyword2013 = [word for words in keyword2013 for word in words]

keyword2014 = cate[cate.year == 2014].keyword 
keyword2014 = [word for words in keyword2014 for word in words]

keyword2015 = cate[cate.year == 2015].keyword 
keyword2015 = [word for words in keyword2015 for word in words]

keyword2016 = cate[cate.year == 2016].keyword 
keyword2016 = [word for words in keyword2016 for word in words]

keyword2017 = cate[cate.year == 2017].keyword 
keyword2017 = [word for words in keyword2017 for word in words]

keyword2018 = cate[cate.year == 2018].keyword 
keyword2018 = [word for words in keyword2018 for word in words]

keyword2019 = cate[cate.year == 2019].keyword 
keyword2019 = [word for words in keyword2019 for word in words]

keyword2020 = cate[cate.year == 2020].keyword 
keyword2020 = [word for words in keyword2020 for word in words]

# %%
len(keyword2000), len(keyword2001),len(keyword2002), len(keyword2003),len(keyword2004), len(keyword2005),len(keyword2006), len(keyword2007)
# Out:
# (522, 689, 1150, 998, 1174, 1348, 1691, 1533)

# %%
len(keyword2008), len(keyword2009),len(keyword2010), len(keyword2011),len(keyword2012), len(keyword2013),  len(keyword2014), len(keyword2015)
# Out:
# (2027, 2718, 2289, 2665, 2488, 4894, 3229, 2523)

# %%
len(keyword2016), len(keyword2017), len(keyword2018), len(keyword2019), len(keyword2020)
# Out:
# (3355, 3840, 3854, 3828, 3786)

# %%
keyword2000[:5]
# Out:
# ['lurking', 'groups', 'group', 'dls', 'fewer']

# %%
count2000 = Counter(keyword2000)
count2001 = Counter(keyword2001)
count2002 = Counter(keyword2002)
count2003 = Counter(keyword2003)
count2004 = Counter(keyword2004)
count2005 = Counter(keyword2005)
count2006 = Counter(keyword2006)
count2007 = Counter(keyword2007)
count2008 = Counter(keyword2008)
count2009 = Counter(keyword2009)
count2010 = Counter(keyword2010)
count2011 = Counter(keyword2011)
count2012 = Counter(keyword2012)
count2013 = Counter(keyword2013)
count2014 = Counter(keyword2014)
count2015 = Counter(keyword2015)
count2016 = Counter(keyword2016)
count2017 = Counter(keyword2017)
count2018 = Counter(keyword2018)
count2019 = Counter(keyword2019)
count2020 = Counter(keyword2020)

# %%
print(count2000.most_common(n=10))
print(count2001.most_common(n=10))
print(count2002.most_common(n=10))
print(count2003.most_common(n=10))
print(count2004.most_common(n=10))
print(count2005.most_common(n=10))
print(count2006.most_common(n=10))
print(count2007.most_common(n=10))
print(count2008.most_common(n=10))
print(count2009.most_common(n=10))
print(count2010.most_common(n=10))
print(count2011.most_common(n=10))
print(count2012.most_common(n=10))
print(count2013.most_common(n=10))
print(count2014.most_common(n=10))
print(count2015.most_common(n=10))
print(count2016.most_common(n=10))
print(count2017.most_common(n=10))
print(count2018.most_common(n=10))
print(count2019.most_common(n=10))
print(count2020.most_common(n=10))
# Out:
# [('Web', 9), ('Internet', 9), ('user', 7), ('users', 7), ('web', 5), ('Business', 4), ('Information', 4), ('to', 4), ('research', 4), ('Risks', 4)]
# [('user', 12), ('web', 9), ('Web', 8), ('data', 6), ('services', 6), ('based', 5), ('applications', 5), ('application', 5), ('page', 5), ('users', 5)]
# [('game', 16), ('games', 15), ('web', 14), ('network', 13), ('services', 10), ('user', 10), ('data', 9), ('service', 9), ('communication', 9), ('xml', 8)]
# [('web', 18), ('services', 16), ('service', 15), ('information', 11), ('data', 8), ('application', 8), ('document', 8), ('game', 7), ('games', 7), ('applications', 6)]
# [('web', 24), ('services', 22), ('service', 19), ('games', 12), ('information', 11), ('new', 10), ('game', 9), ('data', 9), ('users', 9), ('query', 8)]
# [('services', 29), ('service', 24), ('web', 20), ('information', 19), ('user', 16), ('users', 15), ('game', 15), ('games', 11), ('design', 9), ('research', 9)]
# ...

# %%
lst=['user','users','web','data']

for w in lst:
  if w in count2000: 
    del count2000[w]

for w in lst:
  if w in count2001: 
    del count2001[w]

for w in lst:
  if w in count2002: 
    del count2002[w]


for w in lst:
  if w in count2003: 
    del count2003[w]

for w in lst:
  if w in count2004: 
    del count2004[w]

for w in lst:
  if w in count2005: 
    del count2005[w]


for w in lst:
  if w in count2006: 
    del count2006[w]


for w in lst:
  if w in count2007: 
    del count2007[w]


for w in lst:
  if w in count2008: 
    del count2008[w]

for w in lst:
  if w in count2009: 
    del count2009[w]

for w in lst:
  if w in count2010: 
    del count2010[w]


for w in lst:
  if w in count2011: 
    del count2011[w]

for w in lst:
  if w in count2012: 
    del count2012[w]


for w in lst:
  if w in count2013: 
    del count2013[w]

for w in lst:
  if w in count2014: 
    del count2014[w]

for w in lst:
  if w in count2015: 
    del count2015[w]


for w in lst:
  if w in count2016: 
    del count2016[w]


for w in lst:
  if w in count2017: 
    del count2017[w]


for w in lst:
  if w in count2018: 
    del count2018[w]

for w in lst:
  if w in count2019: 
    del count2019[w]

for w in lst:
  if w in count2020: 
    del count2020[w]

# %%
print(count2000.most_common(n=10))
print(count2001.most_common(n=10))
print(count2002.most_common(n=10))
print(count2003.most_common(n=10))
print(count2004.most_common(n=10))
print(count2005.most_common(n=10))
print(count2006.most_common(n=10))
print(count2007.most_common(n=10))
print(count2008.most_common(n=10))
print(count2009.most_common(n=10))
print(count2010.most_common(n=10))
print(count2011.most_common(n=10))
print(count2012.most_common(n=10))
print(count2013.most_common(n=10))
print(count2014.most_common(n=10))
print(count2015.most_common(n=10))
print(count2016.most_common(n=10))
print(count2017.most_common(n=10))
print(count2018.most_common(n=10))
print(count2019.most_common(n=10))
print(count2020.most_common(n=10))
# Out:
# [('Web', 9), ('Internet', 9), ('Business', 4), ('Information', 4), ('to', 4), ('research', 4), ('Risks', 4), ('Using', 3), ('Mining', 3), ('Digital', 3)]
# [('Web', 8), ('services', 6), ('based', 5), ('applications', 5), ('application', 5), ('page', 5), ('language', 5), ('information', 4), ('interfaces', 4), ('pages', 4)]
# [('game', 16), ('games', 15), ('network', 13), ('services', 10), ('service', 9), ('communication', 9), ('xml', 8), ('query', 7), ('queries', 6), ('information', 6)]
# [('services', 16), ('service', 15), ('information', 11), ('application', 8), ('document', 8), ('game', 7), ('games', 7), ('applications', 6), ('models', 6), ('xml', 5)]
# [('services', 22), ('service', 19), ('games', 12), ('information', 11), ('new', 10), ('game', 9), ('query', 8), ('communication', 8), ('applications', 8), ('research', 7)]
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

wordcloud2000 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2000.generate_from_frequencies(count2000)

plt.figure(figsize=(14,8))
# plt.subplot(1,2,1)
plt.imshow(wordcloud2000)
plt.title(f'< 2000 > \n(n_keywords={len(count2000.items())})')
plt.axis('off')


plt.show()

wordcloud2001 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2001.generate_from_frequencies(count2001)

# plt.subplot(1,2,2)
plt.imshow(wordcloud2001)
plt.title(f'< 2001 > \n(n_keywords={len(count2001.items())})')
plt.axis('off')


plt.show()

wordcloud2002 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2002.generate_from_frequencies(count2002)

# plt.subplot(1,2,2)
plt.imshow(wordcloud2002)
plt.title(f'< 2002 > \n(n_keywords={len(count2002.items())})')
plt.axis('off')


plt.show()


wordcloud2003 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2003.generate_from_frequencies(count2003)

# plt.subplot(1,2,2)
plt.imshow(wordcloud2003)
plt.title(f'< 2003 > \n(n_keywords={len(count2003.items())})')
plt.axis('off')


plt.show()

wordcloud2004 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2004.generate_from_frequencies(count2004)

# plt.subplot(1,2,2)
plt.imshow(wordcloud2004)
plt.title(f'< 2004 > \n(n_keywords={len(count2004.items())})')
plt.axis('off')


plt.show()

wordcloud2005 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2005.generate_from_frequencies(count2005)

# plt.subplot(1,2,2)
plt.imshow(wordcloud2005)
plt.title(f'< 2005 > \n(n_keywords={len(count2005.items())})')
plt.axis('off')


plt.show()

wordcloud2006 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2006.generate_from_frequencies(count2006)

# plt.subplot(1,2,2)
plt.imshow(wordcloud2006)
plt.title(f'< 2006 > \n(n_keywords={len(count2006.items())})')
plt.axis('off')


plt.show()

wordcloud2007 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2007.generate_from_frequencies(count2007)

# plt.subplot(1,2,2)
plt.imshow(wordcloud2007)
plt.title(f'< 2007 > \n(n_keywords={len(count2007.items())})')
plt.axis('off')


plt.show()


wordcloud2008 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2008.generate_from_frequencies(count2008)

# plt.subplot(1,2,2)
plt.imshow(wordcloud2008)
plt.title(f'< 2008 > \n(n_keywords={len(count2008.items())})')
plt.axis('off')

plt.show()

wordcloud2009 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2009.generate_from_frequencies(count2009)

# plt.subplot(1,2,2)
plt.imshow(wordcloud2009)
plt.title(f'< 2009 > \n(n_keywords={len(count2009.items())})')
plt.axis('off')


plt.show()

wordcloud2010 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2010.generate_from_frequencies(count2010)

# plt.subplot(1,2,2)
plt.imshow(wordcloud2010)
plt.title(f'< 2010 > \n(n_keywords={len(count2010.items())})')
plt.axis('off')

plt.show()

wordcloud2011 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2011.generate_from_frequencies(count2011)

# plt.subplot(1,2,2)
plt.imshow(wordcloud2011)
plt.title(f'< 2011 > \n(n_keywords={len(count2011.items())})')
plt.axis('off')


plt.show()

wordcloud2012 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2012.generate_from_frequencies(count2012)

# plt.subplot(1,2,2)
plt.imshow(wordcloud2012)
plt.title(f'< 2012 > \n(n_keywords={len(count2012.items())})')
plt.axis('off')

plt.show()

wordcloud2013 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2013.generate_from_frequencies(count2013)

# plt.subplot(1,2,2)
plt.imshow(wordcloud2013)
plt.title(f'< 2013 > \n(n_keywords={len(count2013.items())})')
plt.axis('off')


plt.show()

wordcloud2014 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2014.generate_from_frequencies(count2014)

# plt.subplot(1,2,2)
plt.imshow(wordcloud2014)
plt.title(f'< 2014 > \n(n_keywords={len(count2014.items())})')
plt.axis('off')


plt.show()

wordcloud2015 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2015.generate_from_frequencies(count2015)

# plt.subplot(1,2,2)
plt.imshow(wordcloud2015)
plt.title(f'< 2015 > \n(n_keywords={len(count2015.items())})')
plt.axis('off')


plt.show()

wordcloud2016 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2016.generate_from_frequencies(count2016)

# plt.subplot(1,2,2)
plt.imshow(wordcloud2016)
plt.title(f'< 2016 > \n(n_keywords={len(count2016.items())})')
plt.axis('off')

plt.show()

wordcloud2017 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2017.generate_from_frequencies(count2017)

# plt.subplot(1,2,2)
plt.imshow(wordcloud2017)
plt.title(f'< 2017 > \n(n_keywords={len(count2017.items())})')
plt.axis('off')


plt.show()

wordcloud2018 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2018.generate_from_frequencies(count2018)

# plt.subplot(1,2,2)
plt.imshow(wordcloud2018)
plt.title(f'< 2018 > \n(n_keywords={len(count2018.items())})')
plt.axis('off')


plt.show()

wordcloud2019 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2019.generate_from_frequencies(count2019)

# plt.subplot(1,2,2)
plt.imshow(wordcloud2019)
plt.title(f'< 2019 > \n(n_keywords={len(count2019.items())})')
plt.axis('off')


plt.show()

wordcloud2020 = WordCloud(max_font_size=200, background_color='white', width=800, height=800, stopwords=STOPWORDS)
wordcloud2020.generate_from_frequencies(count2020)

# plt.subplot(1,2,2)
plt.imshow(wordcloud2020)
plt.title(f'< 2020 > \n(n_keywords={len(count2020.items())})')
plt.axis('off')


plt.show()

# plt.tight_layout()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# 생성된 WordCloud를 test.jpg로 보낸다.
# p_wordcloud.to_file('p_wordcloud.jpg')
# n_wordcloud.to_file('n_wordcloud.jpg')
